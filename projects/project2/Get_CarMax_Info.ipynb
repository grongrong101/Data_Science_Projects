# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.carmax.com/car/18409405' 
user_agent = {'User-agent': 'Mozilla/5.0'}
response  = requests.get(url, headers = user_agent)
page = response.text
soup = BeautifulSoup(page, "lxml")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta content="width=device-width, initial-scale=1.0, user-scalable=no" name="viewport"/>
#   <meta content="no" name="msapplication-tap-highlight"/>
#   <link href="https://car-website.carmax.com" rel="preconnect"/>
#   <link href="https://img2.carmax.com" rel="preconnect"/>
#   <link crossorigin="" href="https://s.go-mpulse.net" rel="preconnect"/>
#   <title>
#    Used 2018 Volvo S90 in Philadelphia, Pennsylvania | CarMax
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="CarMax" name="twitter:site"/>
#   <meta content="CarMax" name="twitter:author"/>
#   <meta content="website" property="og:type"/>
#   <meta content="CarMax" property="og:site_name"/>
#   <meta content="2018 Volvo S90" property="og:title"/>
# ...

# %%
make = soup.find(class_ = 'price-mileage__car-title__year-make')

# %%
brand = soup.find(class_ = 'price-mileage__car-title__model-trim')

# %%
value = soup.find(class_ = 'price-mileage__price-container').find(class_ = 'value').find(class_ = 'value')

# %%
mpg = soup.find(class_ = 'mpg')

# %%
miles = soup.find(class_ = 'price-mileage__mileage-container').find(class_ = 'value')

# %%
soup.find(class_ ='saved-count')

# %%
print(liked)
# Out:
# None
