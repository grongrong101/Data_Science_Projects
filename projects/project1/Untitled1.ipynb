# %%
import pandas as pd
turnstile = pd.read_csv('turnstile/cleaned_turnstile_daily.csv')

# %%
turnstile
# Out:
#          Unnamed: 0    C/A  UNIT       SCP        STATION        DATE  \
# 0                 1   A002  R051  02-00-00          59 ST  01/02/2019
# 1                 2   A002  R051  02-00-00          59 ST  01/03/2019
# 2                 3   A002  R051  02-00-00          59 ST  01/04/2019
# 3                 4   A002  R051  02-00-00          59 ST  01/05/2019
# 4                 5   A002  R051  02-00-00          59 ST  01/06/2019
# ...             ...    ...   ...       ...            ...         ...
# 1763877     1768906  TRAM2  R469  00-05-01  RIT-ROOSEVELT  12/27/2018
# 1763878     1768907  TRAM2  R469  00-05-01  RIT-ROOSEVELT  12/28/2018
# 1763879     1768908  TRAM2  R469  00-05-01  RIT-ROOSEVELT  12/29/2018
# 1763880     1768909  TRAM2  R469  00-05-01  RIT-ROOSEVELT  12/30/2018
# 1763881     1768910  TRAM2  R469  00-05-01  RIT-ROOSEVELT  12/31/2018
#
#          ENTRIES   PREV_DATE  PREV_ENTRIES  DAILY_ENTRIES
# 0        6893894  01/01/2019     6892430.0         1464.0
# ...
